# %%
import sys, os
sys.path.append("../")

from src.ingestion.arxiv_loader import download_arxiv_papers

# %%
papers = download_arxiv_papers([
    "2402.06782",   # "Large Language Models as Optimizers"
    "2302.14045",   # "Toolformer"
    "2312.00752"    # "Mamba"
])
papers
# Out:
# Downloading 2402.06782... OK
# Downloading 2302.14045... OK
# Downloading 2312.00752... OK
#
# Downloaded 3 papers. Metadata saved in data/raw/arxiv/metadata.json
# [{'arxiv_id': '2402.06782',
#   'pdf_path': 'data/raw/arxiv/2402.06782.pdf',
#   'url': 'https://arxiv.org/pdf/2402.06782.pdf'},
#  {'arxiv_id': '2302.14045',
#   'pdf_path': 'data/raw/arxiv/2302.14045.pdf',
#   'url': 'https://arxiv.org/pdf/2302.14045.pdf'},
#  {'arxiv_id': '2312.00752',
#   'pdf_path': 'data/raw/arxiv/2312.00752.pdf',
#   'url': 'https://arxiv.org/pdf/2312.00752.pdf'}]

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))


if project_root not in sys.path:
    sys.path.append(project_root)

print("Project root added:", project_root)
# Out:
# Project root added: /Users/aliiii/Desktop/projects/Rag project

# %%
from src.ingestion.arxiv_loader import *
from src.processing.parser import parse_pdf

# %%
pdf_paths = download_arxiv_papers("data/raw/arxiv")

pdf_paths
# Out:
# Fetching latest papers from arXiv (cs.LG)…
# Downloading 2511.17489v1 … OK
# Downloading 2511.17475v1 … OK
# Downloading 2511.17473v1 … OK
# Downloading 2511.17467v1 … OK
# Downloading 2511.17446v1 … OK
# ['data/raw/arxiv/2511.17489.pdf',
#  'data/raw/arxiv/2511.17475.pdf',
#  'data/raw/arxiv/2511.17473.pdf',
#  'data/raw/arxiv/2511.17467.pdf',
#  'data/raw/arxiv/2511.17446.pdf']

# %%
from src.ingestion.arxiv_loader import download_arxiv_papers
pdfs = download_arxiv_papers()
# Out:
# Fetching latest papers from arXiv (cs.LG)…
# Downloading 2511.17489v1 … OK
# Downloading 2511.17475v1 … OK
# Downloading 2511.17473v1 … OK
# Downloading 2511.17467v1 … OK
# Downloading 2511.17446v1 … OK
